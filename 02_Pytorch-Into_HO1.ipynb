# %% [markdown]
# colab:
#
# https://colab.research.google.com/drive/1wXhqWPQb1V5KXvrhYMLA7f8C-9adD_RK?usp=sharing
#
#
# video link:
#
# https://drive.google.com/file/d/1kD9rjDo4noZn84T-oHwcOESSWPHqXpmO/view?usp=sharing

# %% [markdown]
# # Introduction to Pytorch
#
# PyTorch is a machine learning framework produced by Facebook in October 2016. It is open source, and is based on the popular Torch library. PyTorch is designed to provide good flexibility and high speeds for deep neural network implementation.
#
#
# Pytorch doc:
#
# https://pytorch.org/docs/stable/index.html

# %% [markdown]
# ![pytorch_1-1024x289.png](data:image/png;base64,...)

# %% [markdown]
# # Tensor

# %%
import torch
import numpy as np

# %%
a = [i for i in range(5)]
print(a)
print(type(a))
# Out:
# [0, 1, 2, 3, 4]
# <class 'list'>

# %%
# turn list to tensor
b = torch.tensor(a, , dtype=torch.float32) # dtype=torch.float32 
print(b)
print(b.shape)
print(b.device)
print(b.dtype)
# Out:
# tensor([0, 1, 2, 3, 4])
# torch.Size([5])
# cpu
# torch.int64

# %%
# bumpy array
c = np.random.normal(0,2,size=(2,5))
c
# Out:
# array([[-1.32814978, -0.79549134,  1.33025531, -1.10851833, -3.32975319],
#        [-2.37727157, -2.00930408,  0.72586325, -3.24041134, -0.90439338]])

# %%
# turn array numpy to tensor
d = torch.from_numpy(c)
d
# Out:
# tensor([[-1.3281, -0.7955,  1.3303, -1.1085, -3.3298],
#         [-2.3773, -2.0093,  0.7259, -3.2404, -0.9044]], dtype=torch.float64)

# %%
# turn tensor to numpy
e = d.numpy()
e
# Out:
# array([[-1.32814978, -0.79549134,  1.33025531, -1.10851833, -3.32975319],
#        [-2.37727157, -2.00930408,  0.72586325, -3.24041134, -0.90439338]])

# %%
# add and sub and div
d = torch.rand(1,5)
print(d)

add = torch.add(d, 20)
print(add)

sub = torch.sub(d, 0.8)
print(sub)

div = torch.div(d, 2)
print(div)
# Out:
# tensor([[0.5602, 0.7647, 0.4547, 0.2293, 0.6018]])
# tensor([[20.5602, 20.7647, 20.4547, 20.2293, 20.6018]])
# tensor([[-0.2398, -0.0353, -0.3453, -0.5707, -0.1982]])
# tensor([[0.2801, 0.3823, 0.2273, 0.1147, 0.3009]])

# %%
# slicing
d = torch.rand(3,5)
print(d)
print(d[:,2])
print(d[1,1])
# Out:
# tensor([[0.9926, 0.0074, 0.5980, 0.0667, 0.2749],
#         [0.4931, 0.9170, 0.7608, 0.0320, 0.7389],
#         [0.5596, 0.7701, 0.4481, 0.5496, 0.8384]])
# tensor([0.5980, 0.7608, 0.4481])
# tensor(0.9170)

# %%
a = torch.tensor([[1, 2],[3, 4]])
print(a)
print(a.shape)
# Out:
# tensor([[1, 2],
#         [3, 4]])
# torch.Size([2, 2])

# %%
torch.random.manual_seed(5)

# %%
a = torch.randint(3,10,(3,5))
a
# Out:
# tensor([[4, 8, 5, 6, 9],
#         [4, 4, 6, 8, 7],
#         [3, 9, 7, 5, 6]])

# %%
b = torch.reshape(a, (5,3))
b
# Out:
# tensor([[4, 8, 5],
#         [6, 9, 4],
#         [4, 6, 8],
#         [7, 3, 9],
#         [7, 5, 6]])

# %%
c = torch.cat([a,a,a],dim=0)
c
# Out:
# tensor([[4, 8, 5, 6, 9],
#         [4, 4, 6, 8, 7],
#         [3, 9, 7, 5, 6],
#         [4, 8, 5, 6, 9],
#         [4, 4, 6, 8, 7],
#         [3, 9, 7, 5, 6],
#         [4, 8, 5, 6, 9],
#         [4, 4, 6, 8, 7],
#         [3, 9, 7, 5, 6]])

# %%
# matrix multipe
torch.matmul(a,a.T)
# Out:
# tensor([[222, 189, 203],
#         [189, 181, 172],
#         [203, 172, 200]])

# %%
a @ a.T
# Out:
# tensor([[222, 189, 203],
#         [189, 181, 172],
#         [203, 172, 200]])

# %%
a.matmul(a.T)
# Out:
# tensor([[222, 189, 203],
#         [189, 181, 172],
#         [203, 172, 200]])

# %%
# elementwise matrix multiple
torch.mul(a,a)
# Out:
# tensor([[16, 64, 25, 36, 81],
#         [16, 16, 36, 64, 49],
#         [ 9, 81, 49, 25, 36]])

# %%
a * a
# Out:
# tensor([[16, 64, 25, 36, 81],
#         [16, 16, 36, 64, 49],
#         [ 9, 81, 49, 25, 36]])

# %%
a.mul(a)
# Out:
# tensor([[16, 64, 25, 36, 81],
#         [16, 16, 36, 64, 49],
#         [ 9, 81, 49, 25, 36]])

# %%
print(torch.argmax(a))
print(torch.max(a).item())
print(torch.sum(a)) 
print(torch.abs(a))
# .item()
# Out:
# tensor(4)
# 9
# tensor(91)
# tensor([[4, 8, 5, 6, 9],
#         [4, 4, 6, 8, 7],
#         [3, 9, 7, 5, 6]])

# %%
a1 = torch.randint(3,10,(3,5))
a1
# Out:
# tensor([[5, 7, 8, 9, 8],
#         [6, 4, 3, 7, 4],
#         [3, 4, 6, 9, 8]])

# %%
a2 = torch.randint(3,10,(3,5))
a2
# Out:
# tensor([[6, 8, 8, 6, 5],
#         [8, 8, 8, 7, 3],
#         [5, 4, 5, 9, 5]])

# %%
torch.eq(a1,a2) # same dimensions
# Out:
# tensor([[False, False,  True, False, False],
#         [False, False, False,  True, False],
#         [False,  True, False,  True, False]])

# %%
torch.save(a,'weight.pt')

# %%
torch.load('/content/weight.pt')
# Out:
# tensor([[4, 8, 5, 6, 9],
#         [4, 4, 6, 8, 7],
#         [3, 9, 7, 5, 6]])

# %% [markdown]
# you can use numpy for generating random numbers and then turn them into torch tensor

# %%
a.device
# Out:
# device(type='cpu')

# %%
# the CUDA tool is a development environment for creating high performance GPU accelerated aplications
# that for this you need an NVIDIA GPU on your machine
a = a.to('cuda')

# %%
torch.cuda.is_available()

# %%
torch.cuda.get_device_name()

# %% [markdown]
# notice: numpy array and tensor have a same memory location if tensor on cpu.

# %% [markdown]
# # implement gradient numpy

# %%
import numpy as np

# initial
X = np.array([1,2,3,4])
Y = np.array([3,6,9,12])
w = np.random.random()
print(w)
# loss
def loss(y, y_pred):
    return ((y - y_pred)**2).mean()

# gradient
# MSE: 1/N * (w*x - y)**2
# d/dw : 1/N 2x (w*x - y)
def gradient(x, y, y_predict):
    return np.dot(2*x, y_predict - y).mean()

# training
lr = 0.01
for epoch in range(10):
    # forward
    y_pred = X * w

    # loss
    l = loss(Y, y_pred)

    # gradient
    dw = gradient(X, Y, y_pred)

    # update weight
    w -= lr * dw

    if epoch % 1 == 0:
        print(f"epoch: {epoch + 1} , w: {w:.3f} , loss: {l:.5f}")

# %% [markdown]
# learning rate visualization
#
# https://sut-ai.github.io/supplementary/notebooks/search_in_continuous_space/

# %% [markdown]
# # implement gradient torch

# %%
# replace loss function and use autograd
import torch
import torch.nn as nn
# initial
X = torch.tensor([1,2,3,4], dtype=torch.float32)
Y = torch.tensor([3,6,9,12],dtype=torch.float32)
w = torch.tensor(0.0,requires_grad=True) # requires_grad parameter tells PyTorch to store gradients

# loss
# def loss(y, y_pred):
#     return ((y - y_pred)**2).mean()

# # gradient
# # MSE: 1/N * (w*x - y)**2
# # d/dw : 1/N 2x (w*x - y)
# def gradient(x, y, y_predict):
#     return np.dot(2*x, y_predict - y).mean()

loss = nn.MSELoss()

lr = 0.05

for epoch in range(10):
    # forward
    y_pred = w * X

    # loss
    l = loss(Y, y_pred)

    # gradient
    # dw = gradient(X, Y, y_pred)
    l.backward()

    # update weight
    # w -= lr * dw
    with torch.no_grad():
        w -= lr * w.grad

    w.grad.zero_() ##

    if epoch % 1 == 0:
        print(f"epoch: {epoch + 1} , w: {w:.3f} , loss: {l:.3f}")

# %%
# zero_grad() in autograd
x = torch.tensor([2.0], requires_grad=True)
print(x.grad)

# %%
y = x * x * 5 # 5x^2
y.backward()
print(x.grad) # d(y)/d(x) = d(5x^2)/d(x) = 10x = 20

# %%
z = x * x * 5 # 5x^2
x.grad.zero_()
z.backward()
print(x.grad)

# %%
# use optimizer 
import torch

# initial
X = torch.tensor([1,2,3,4], dtype=torch.float32)
Y = torch.tensor([3,6,9,12],dtype=torch.float32)
w = torch.tensor(0.0,requires_grad=True) 

# loss
lr = 0.05
loss = nn.MSELoss()
optimizer = torch.optim.SGD([w], lr=lr)

for epoch in range(10):
    # forward
    y_pred = w * X

    # loss
    l = loss(Y, y_pred)

    # gradient
    l.backward()

    # update weight
    # with torch.no_grad():
    #     w -= lr * w.grad
    optimizer.step()

    # w.grad.zero_()
    optimizer.zero_grad()

    if epoch % 1 == 0:
        print(f"epoch: {epoch + 1} , w: {w:.3f} , loss: {l:.8f}")

# %%
# use model
import torch
import torch.nn as nn
# initial
X = torch.tensor([[1],[2],[3],[4]], dtype=torch.float32)
Y = torch.tensor([[3],[6],[9],[12]],dtype=torch.float32)
# w = torch.tensor(0.0,requires_grad=True)

n_sample, n_feature = X.shape
input_size = n_feature
output_size = n_feature
model = nn.Linear(input_size, output_size)

# loss
lr = 0.1
loss = nn.MSELoss()
# optimizer = torch.optim.SGD([w], lr=lr)
optimizer = torch.optim.SGD(model.parameters(), lr=lr)

for epoch in range(10):
    # forward
    # y_pred = w * X
    y_pred = model(X)

    # loss
    l = loss(Y, y_pred)

    # gradient
    l.backward()

    # update weight
    # with torch.no_grad():
    #     w -= lr * w.grad
    optimizer.step()

    # w.grad.zero_()
    optimizer.zero_grad()

    if epoch % 1 == 0:
        [w, b] = model.parameters() 
        print(f"epoch: {epoch + 1} , w: {w[0][0].item():.3f} , loss: {l:.5f}")

# %%
# use GPU
import torch
import torch.nn as nn
# initial
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
X = torch.tensor([[1],[2],[3],[4]], dtype=torch.float32, device=device)
Y = torch.tensor([[3],[6],[9],[12]],dtype=torch.float32, device=device)

n_sample, n_feature = X.shape
input_size = n_feature
output_size = n_feature
model = nn.Linear(input_size, output_size)
model.to(device)
# loss
lr = 0.05
loss = nn.MSELoss()
optimizer = torch.optim.SGD(model.parameters(), lr=lr)

for epoch in range(10):
    # forward
    y_pred = model(X)

    # loss
    l = loss(Y, y_pred)

    # gradient
    l.backward()

    # update weight
    optimizer.step()

    optimizer.zero_grad()

    if epoch % 1 == 0:
        [w, b] = model.parameters() 
        print(f"epoch: {epoch + 1} , w: {w[0][0].item():.3f} , loss: {l:.5f}")

# %%
for i in model.parameters():
    print(i.is_cuda)

# %% [markdown]
# # activation function

# %%
import torch.nn as nn
import torch

# %%
'''
1) Step Function
2) Sigmoid
3) TanH
4) RelU
5) Leaky ReLU
6) Softmax
'''

# %% [markdown]
# Activation Function apply a non-linear transformation and decide whether a nouron should be activated or not.
#
# why linear activation function not good enough??

# %% [markdown]
# # soft max & Cross Entropy loss

# %% [markdown]
# ![softmax.png](data:image/png;base64,...)

# %% [markdown]
# ![softmax.png](data:image/png;base64,...)

# %%
import numpy as np

def softmax(x):
    return (np.exp(x))/(np.sum(np.exp(x)))

input = np.array([2,1,0.1])
softmax(input)

# %%
import torch
import torch.nn as nn
input = torch.tensor([2,1,0.1])
torch.softmax(input, dim=0)
# m = nn.Softmax(dim=0)
# m(input)

# %% [markdown]
# ![softmax.png](data:image/png;base64,...)

# %%
import numpy as np

def CrossEntropy(actual, predicted):
    return -(np.sum(actual*np.log(predicted))) # / float(predicted.shape[0])

Y = np.array([1, 0, 0])
Y_pred_good = np.array([0.7, 0.2, 0.1])
Y_pred_bad = np.array([0.1, 0.3, 0.6])

l1 = CrossEntropy(Y, Y_pred_good)
l2 = CrossEntropy(Y, Y_pred_bad)
print(l1, l2)

# %% [markdown]
# ![softmax.png](data:image/png;base64,...)

# %%
import torch.nn as nn
loss = nn.CrossEntropyLoss()
# samples
Y = torch.tensor([0]) # no need to one hot encoding
Y_pred_good = torch.tensor([[2, 1, 0.1]]) # no need softmax 
Y_pred_bad = torch.tensor([[0.5, 2, 0.3]])
# 
l1 = loss(Y_pred_good, Y)
l2 = loss(Y_pred_bad, Y)
#
print(l1.item(), l2.item())

# %% [markdown]
# notice: we use sigmoid at the end in BCEloss for Binary problem
# for example: is it a dog? if output higher than 0.5 Yes.
#
# in the video, I replace sigmoid with softmax and this is wrong, sigmoid was true

# %% [markdown]
# # Feed Forward

# %% [markdown]
# ***Datasets and DataLoader***
#
# **epoch** = 1 forward and backward pass of all training samples
#
# **batch_size** = nimber of training samples in one forward & backward pass
#
# **num_iteration** = number of passes, each pass using [batch_size] number of samples
#
# exmple: 100 samples, batch_size=20 --> 100/20 = 5 iteration for 1 epoch

# %%
# MNIST
# Dataloader, Transformation
# Multilayer Neural Net, activation function
# loss and optimizer
# training loop
# model evalution
# GPU support

# %%
import torch
import torch.nn as nn
import torchvision # for dataset
from torch.utils.data import Dataset, DataLoader
import numpy as np
import matplotlib.pyplot as plt
import torchvision.transforms as transforms

# %%
# device config
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# define hyper parameters
input_size = 784 # image size in MNIST 28*28
hidden_size = 1000
num_class = 10
num_epoch = 2
batch_size = 100
learning_rate = 0.001

# MNIST
train_dataset = torchvision.datasets.MNIST(root='./data', train=True, transform=transforms.ToTensor(), download=True) 
test_dataset = torchvision.datasets.MNIST(root='./data', train=False, transform=transforms.ToTensor(), download=True)

train_loader = DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(dataset=test_dataset, batch_size=batch_size, shuffle=False) # shuffle in test_dataset doesnt matter for evaluation

# one batch of data
examples = iter(train_loader)     # objects
samples, labels = examples.next() # unpack examples

print(samples.shape, labels.shape)

for i in range(6):
    plt.subplot(2, 3, i+1)
    plt.imshow(samples[i][0], cmap='gray') # cmap: color map
plt.show()

# %%
# create our network
class NeuralNet(nn.Module):
    def __init__(self, input_size, hidden_size, num_class): # num_class = output size
        super(NeuralNet, self).__init__()
        # our layers
        self.l1 = nn.Linear(input_size, hidden_size)
        self.relu = nn.ReLU()
        self.l2 = nn.Linear(hidden_size, num_class)

    def forward(self, x):
        out = self.l1(x)
        out = self.relu(out)
        out = self.l2(out)
        return out # dont use softmax for CrossEntropyloss

model = NeuralNet(input_size,hidden_size,num_class)
model.to(device)

# %%
# loss and optimizer
criterion = nn.CrossEntropyLoss() # dont use softmax
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# training loop
n_total_steps = len(train_loader)
for epoch in range(num_epoch):
    for i, (images, labels) in enumerate(train_loader):
        # 100, 1, 28, 28
        # 100, 784
        images = images.reshape(-1, 28*28).to(device)
        lables = labels.to(device)

        # forward pass and loss
        outputs = model(images)
        loss = criterion(outputs, lables)

        # backward pass
        loss.backward()
        optimizer.step()

        optimizer.zero_grad()
        
        # print the loss
        if (i+1)%100 ==0:
            print(f"epoch: {epoch+1} / {num_epoch} , step {i+1}/{n_total_steps}, loss = {loss.item():.5f}")

# %%
for i in model.parameters():
    print(i.is_cuda)

# %%
# test
with torch.no_grad():
    n_correct = 0
    n_samples = 0
    for images, labels in test_loader:
        images = images.reshape(-1, 28*28).to(device)
        labels = labels.to(device)
        outputs = model(images)

        _, prediction = torch.max(outputs, 1) # along the dimension 1
        n_samples += labels.shape[0]
        n_correct += (prediction == labels).sum().item()

    acc = 100*(n_correct / n_samples)
    print(f"accuracy = {acc}")
